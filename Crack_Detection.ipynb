# %%
import cv2
import numpy as np

# %%
# !pip install roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="71axtLByb0PTSfiNXQ5B")
project = rf.workspace("manjari").project("image-segmentation-pipe-crack")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 15.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 64.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to image-segmentation-pipe-crack-1 in yolov8:: 100%|██████████| 94/94 [00:00<00:00, 6621.95it/s]

# %%
def pipe_detection(frame):
    """Detects pipes in a video frame using a combination of techniques."""

    # Preprocessing
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray, (5, 5), 0)
     # Edge detection and morphological operations
    edges = cv2.Canny(blur, 50, 150)
    kernel = np.ones((5, 5), np.uint8)
    closing = cv2.morphologyEx(edges, cv2.MORPH_CLOSE, kernel)
     # Filter contours based on aspect ratio, area, and circularity
    pipes = []
    for cnt in contours:
        x, y, w, h = cv2.boundingRect(cnt)
        aspect_ratio = float(w) / h
        area = cv2.contourArea(cnt)
        circularity = 4 * np.pi * area / (cv2.arcLength(cnt, True) ** 2)
        if 0.5 < aspect_ratio < 2 and 100 < area < 10000 and 0.6 < circularity < 1:  # Adjust thresholds as needed
            pipes.append((x, y, w, h))

    return pipes

# %%
import cv2

# Try different camera indices
for i in range(5):  # Check indices 0 to 4
    cap = cv2.VideoCapture(i)
    if cap.isOpened():
        print(f"Camera found at index {i}")
        break
    else:
        print(f"Camera not found at index {i}")
        cap.release()  # Release the camera if not opened

if cap.isOpened():
    while True:
        ret, frame = cap.read()

        if not ret:
            print("Error: Failed to capture frame from camera.")
            break

        # Detect pipes
        detected_pipes = pipe_detection(frame)

        # ... rest of your code ...

    cap.release()
else:
    print("No camera found.")
# Out:
# Camera not found at index 0
# Camera not found at index 1
# Camera not found at index 2
# Camera not found at index 3
# Camera not found at index 4
# No camera found.
